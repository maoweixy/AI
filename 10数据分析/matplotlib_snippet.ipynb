# %%
from matplotlib import rcParams
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import pandas as pd
import numpy as np

# %% [markdown]
# # configuration配置
# https://blog.csdn.net/qq_27825451/article/details/82732675

# %%
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS'] #正常显示中文
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
plt.rc('figure', figsize=(10, 10))

# %%
data_train = pd.read_csv('train.csv')

# %% [markdown]
# # Figure、Axes

# %%
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)


# Create just a figure and only one subplot
fig, ax = plt.subplots(figsize=(15, 10))
ax.plot(x, y)
ax.set_title('Simple plot')

# Create two subplots and unpack the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# %%
fig = plt.figure(figsize=(10,10))
data_train.Age[data_train.Survived == 1].plot(kind='kde')   
data_train.Age[data_train.Survived == 0].plot(kind='kde')
plt.xlabel(u"年龄")# plots an axis lable
plt.ylabel(u"密度") 
plt.legend(('存活', '未存活'),loc='best') # sets our legend for our graph.

# %%
fig = plt.figure(figsize=(20,20))
fig.set(alpha=0.9)  # 设定图表颜色alpha参数

plt.subplot2grid((2,3),(0,0))             # 在一张大图里分列几个小图
data_train.Age[data_train.Survived == 1].plot.hist()
# data_train.Age[data_train.Survived == 0].plot.kde()
plt.title(u"获救、未获救年龄分布") # 标题
plt.ylabel(u"人数")  
plt.legend(('获救', '未获救', '年龄'), loc='best') # sets our legend for our graph. 

plt.subplot2grid((2,3),(0,1))
# data_train.Pclass.value_counts().plot(kind="bar")
data_train.Age.plot.hist()
plt.ylabel(u"人数")
plt.title(u"乘客年纪分布")

plt.subplot2grid((2,3),(0,2))
plt.scatter(data_train.Survived, data_train.Age)
plt.ylabel(u"年龄")                         # 设定纵坐标名称
plt.grid(b=True, which='major', axis='y') 
plt.title(u"按年龄看获救分布 (1为获救)")


plt.subplot2grid((2,3),(1,0), colspan=2)
# data_train.Age[data_train.Pclass == 1].plot(kind='kde') 
data_train.Age[data_train.Pclass == 1].plot.kde()   
data_train.Age[data_train.Pclass == 2].plot(kind='kde')
data_train.Age[data_train.Pclass == 3].plot(kind='kde')
plt.xlabel(u"年龄")# plots an axis lable
plt.ylabel(u"密度") 
plt.title(u"各等级的乘客年龄分布")
plt.grid(True)
plt.legend((u'头等舱', u'2等舱',u'3等舱'),loc='best') # sets our legend for our graph. 


plt.subplot2grid((2,3),(1,2))
data_train.Embarked.value_counts().plot(kind='bar')
plt.title(u"各登船口岸上船人数")
plt.ylabel(u"人数")
# Out:
# Text(0, 0.5, '人数')

# %% [markdown]
# # 画图种类

# %% [markdown]
# ## 普通图

# %%
x = np.linspace(-3, 3, 50)
y1 = 2*x + 1
y2 = x**2

plt.figure()

plt.plot(x, y2)
plt.plot(x, y1, color='red', linewidth=1.0, linestyle='--')

#坐标轴范围
plt.xlim(-1, 2)
plt.ylim(-2, 3)
#坐标轴名称
plt.xlabel('I am x')
plt.ylabel('I am y')

#x轴刻度
new_ticks = np.linspace(-1, 2, 5)
plt.xticks(new_ticks)
#y轴刻度以及刻度名称
plt.yticks([-2, -1.8, -1, 1.22, 3],[r'$really\ bad$', r'$bad$', r'$normal$', r'$good$', r'$really\ good$'])

#获取坐标轴
ax = plt.gca()
#设置坐标轴边框颜色
ax.spines['right'].set_color('red')
ax.spines['top'].set_color('none')
#设置边框位置
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data',0))

# %% [markdown]
# ## Bar（条形图或柱状图）

# %%
n = 12
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)

plt.figure(figsize=(10, 6))
plt.bar(X, +Y1, edgecolor='white')
plt.bar(X, -Y2, edgecolor='white')

plt.xlim(-.5, n)
plt.ylim(-1.25, 1.25)

for x, y in zip(X, Y1):
    # ha: horizontal alignment
    # va: vertical alignment
#     plt.text(x, y, '%.2f' % y, ha='center', va='top')
    plt.text(x, y, '%.2f' % y, ha='center')

for x, y in zip(X, Y2):
    # ha: horizontal alignment
    # va: vertical alignment
    plt.text(x, -y, '%.2f' % y, ha='center', va='top')

# %% [markdown]
# ## Scatter（散点图）

# %%
n = 1024    # data size
X = np.random.normal(0, 1, n) # 每一个点的X值
Y = np.random.normal(0, 1, n) # 每一个点的Y值
T = np.arctan2(Y,X) # for color value

plt.scatter(X, Y, s=75, c=T, alpha=.5)

plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# ## Pie（饼图）

# %% [markdown]
# # seaborn
#
# https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# ## sns配置
#
# 声明使用 Seaborn 样式 ： sns.set()
#
# sns.set() 的默认参数为：sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)
#
# context='' 参数控制着默认的画幅大小，分别有 {paper, notebook, talk, poster} 四个值。其中，poster > talk > notebook > paper。
# style='' 参数控制默认样式，分别有 {darkgrid, whitegrid, dark, white, ticks}，你可以自行更改查看它们之间的不同。
# palette='' 参数为预设的调色板。分别有 {deep, muted, bright, pastel, dark, colorblind} 等，你可以自行更改查看它们之间的不同。
# 剩下的 font='' 用于设置字体，font_scale= 设置字体大小，color_codes= 不使用调色板而采用先前的 'r' 等色彩缩写。

# %%
sns.set()

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 关联图 relplot

# %% [markdown]
# ### 散点图 scatter

# %%
sns.relplot(x="total_bill", y="tip", data=tips);

# %% [markdown]
# ### 折线图 line

# %%
plt.grid(True)
sns.distplot(data.loc[(data["Survived"] == 0) & (train["Age"].notnull()), 'Age'], kde=False)
sns.distplot(data.loc[(data["Survived"] == 1) & (train["Age"].notnull()), 'Age'], kde=False)

# %%
train = pd.read_csv('train.csv')
g = sns.kdeplot(train["Age"][(train["Survived"] == 0) & (train["Age"].notnull())], color="Red", shade = True)
g = sns.kdeplot(train["Age"][(train["Survived"] == 1) & (train["Age"].notnull())], color="Blue", shade= True)
g.set_xlabel("Age")
g.set_ylabel("Frequency")
g.legend(["Not Survived","Survived"])

# %% [markdown]
# ## 类别图 catplot

# %% [markdown]
# ### 散点图

# %%
sns.catplot(x="day", y="total_bill", data=tips)
sns.catplot(x="day", y="total_bill", kind='swarm' ,data=tips)

# %% [markdown]
# ### 箱线图 box

# %%
sns.boxplot("day", y="total_bill", data=tips)
plt.figure()
#画出Dataframe中所有的连续性数据
sns.boxplot(data=tips)
plt.figure()
#增强箱线图，基本原理是用一系列的箱图代替了延伸线，绘制出更多的分位数来提供数据分布的信息，对大数据时代的数据可视化非常有帮助
sns.boxenplot(data=tips)

# %% [markdown]
# ### 条形图 bar

# %%
titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic);

# %%
#计数
sns.catplot(x="deck", kind="count", palette="ch:.25", data=titanic);

# %%
#分类
sns.catplot(x="deck", hue="class", kind="count",
            data=titanic);

# %%
#分成多个图比较
sns.catplot(x="deck", col="class", kind="count",
            data=titanic);

# %% [markdown]
# ## 热力图

# %%
corr = tips.corr()
print(corr)
sns.heatmap(corr, square=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# ### 条形图 bar

# %% [markdown]
# # pandas
